# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Input, Dense, Reshape, Flatten, Dropout
from tensorflow.keras.layers import BatchNormalization, Activation, LeakyReLU, UpSampling2D, Conv2D
from tensorflow.keras.models import Sequential, Model

import numpy as np
import matplotlib.pyplot as plt

# %%
# 생성자 모델을 만듭니다.
generator = Sequential()
generator.add(Dense(128*7*7, input_dim=100, activation=LeakyReLU(0.2)))
generator.add(BatchNormalization())
generator.add(Reshape((7, 7, 128)))
generator.add(UpSampling2D())
generator.add(Conv2D(64, kernel_size=5, padding='same'))
generator.add(BatchNormalization())
generator.add(Activation(LeakyReLU(0.2)))
generator.add(UpSampling2D())
generator.add(Conv2D(1, kernel_size=5, padding='same', activation='tanh'))
# Out:
# c:\ProgramData\anaconda3\envs\cv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:tensorflow:From c:\ProgramData\anaconda3\envs\cv\lib\site-packages\keras\src\backend\tensorflow\core.py:204: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.

# %%
generator.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 6272)           │       633,472 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 6272)           │        25,088 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 7, 7, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d (UpSampling2D)    │ (None, 14, 14, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 14, 14, 64)     │       204,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 14, 14, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 14, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_1 (UpSampling2D)  │ (None, 28, 28, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 28, 28, 1)      │         1,601 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 865,281 (3.30 MB)
#  Trainable params: 852,609 (3.25 MB)
#  Non-trainable params: 12,672 (49.50 KB)

# %%
# 판별자 모델을 만듭니다.
discriminator = Sequential()
discriminator.add(Conv2D(64, kernel_size=5, strides=2, input_shape=(28,28,1), padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Conv2D(128, kernel_size=5, strides=2, padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Flatten())
discriminator.add(Dense(1, activation='sigmoid'))
discriminator.compile(loss='binary_crossentropy', optimizer='adam')
discriminator.trainable = False
# Out:
# c:\ProgramData\anaconda3\envs\cv\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
discriminator.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_2 (Conv2D)               │ (None, 14, 14, 64)     │         1,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 14, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 14, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 7, 7, 128)      │       204,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 7, 7, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 7, 7, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 6272)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │         6,273 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 212,865 (831.50 KB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 212,865 (831.50 KB)

# %%
# 생성자와 판별자 모델을 연결시키는 gan 모델을 만듭니다.
ginput = Input(shape=(100,))
dis_output = discriminator(generator(ginput))
gan = Model(ginput, dis_output)
gan.compile(loss='binary_crossentropy', optimizer='adam')
gan.summary()
# Out:
# Model: "functional_17"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential (Sequential)         │ (None, 28, 28, 1)      │       865,281 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_1 (Sequential)       │ (None, 1)              │       212,865 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,078,146 (4.11 MB)
#  Trainable params: 852,609 (3.25 MB)
#  Non-trainable params: 225,537 (881.00 KB)

# %%
# 신경망을 실행시키는 함수를 만듭니다.
def gan_train(epoch, batch_size, saving_interval):

  # MNIST 데이터를 불러옵니다.

  (X_train, _), (_, _) = mnist.load_data()  # 앞서 불러온 적 있는 MNIST를 다시 이용합니다. 단, 테스트 과정은 필요 없고 이미지만 사용할 것이기 때문에 X_train만 불러왔습니다.
  X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32')
  X_train = (X_train - 127.5) / 127.5  # 픽셀 값은 0에서 255 사이의 값입니다. 이전에 255로 나누어 줄때는 이를 0~1 사이의 값으로 바꾸었던 것인데, 여기서는 127.5를 빼준 뒤 127.5로 나누어 줌으로 인해 -1에서 1사이의 값으로 바뀌게 됩니다.
  # X_train.shape, Y_train.shape, X_test.shape, Y_test.shape

  true = np.ones((batch_size, 1))
  fake = np.zeros((batch_size, 1))

  for i in range(epoch):
    # 실제 데이터를 판별자에 입력하는 부분입니다.
    idx = np.random.randint(0, X_train.shape[0], batch_size)
    imgs = X_train[idx]
    d_loss_real = discriminator.train_on_batch(imgs, true)

    # 가상 이미지를 판별자에 입력하는 부분입니다.
    noise = np.random.normal(0, 1, (batch_size, 100))
    gen_imgs = generator.predict(noise)
    d_loss_fake = discriminator.train_on_batch(gen_imgs, fake)

    # 판별자와 생성자의 오차를 계산합니다.
    d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)
    g_loss = gan.train_on_batch(noise, true)

    print('epoch:%d' % i, end=" ") 
    print(f' d_loss:{d_loss:.4f}', end=" ")
    print(' g_loss:', g_loss)

    # 이 부분은 중간 과정을 이미지로 저장해 주는 부분입니다. 본 장의 주요 내용과 관련이 없어
    # 소스 코드만 첨부합니다. 만들어진 이미지들은 gan_images 폴더에 저장됩니다.
    if i % saving_interval == 0:
        #r, c = 5, 5
        noise = np.random.normal(0, 1, (25, 100))
        gen_imgs = generator.predict(noise)

        # Rescale images 0 - 1
        gen_imgs = 0.5 * gen_imgs + 0.5

        fig, axs = plt.subplots(5, 5)
        count = 0
        for j in range(5):
            for k in range(5):
                axs[j, k].imshow(gen_imgs[count, :, :, 0], cmap='gray')
                axs[j, k].axis('off')
                count += 1
        fig.savefig("./data/gan_images/gan_mnist_%d.png" % i)

# %%
gan_train(2001, 32, 200)  # 2000번 반복되고, 배치 사이즈는 32,  200번마다 결과가 저장되게 하였습니다.
# Out:
# c:\ProgramData\anaconda3\envs\cv\lib\site-packages\keras\src\backend\tensorflow\trainer.py:75: UserWarning: The model does not have any trainable weights.
#   warnings.warn("The model does not have any trainable weights.")
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# epoch:0  d_loss:0.6477  g_loss: [array(0.6641669, dtype=float32), array(0.6641669, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_train_function.<locals>.one_step_on_iterator at 0x0000020408EB34C0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_train_function.<locals>.one_step_on_iterator at 0x000002040A4CB430> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# epoch:1  d_loss:0.6610  g_loss: [array(0.66698384, dtype=float32), array(0.66698384, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# epoch:2  d_loss:0.6626  g_loss: [array(0.66717476, dtype=float32), array(0.66717476, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# epoch:3  d_loss:0.6645  g_loss: [array(0.6680977, dtype=float32), array(0.6680977, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# epoch:4  d_loss:0.6668  g_loss: [array(0.669534, dtype=float32), array(0.669534, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:5  d_loss:0.6685  g_loss: [array(0.6711313, dtype=float32), array(0.6711313, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:6  d_loss:0.6698  g_loss: [array(0.6718406, dtype=float32), array(0.6718406, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# epoch:7  d_loss:0.6702  g_loss: [array(0.67215735, dtype=float32), array(0.67215735, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# epoch:8  d_loss:0.6711  g_loss: [array(0.67292565, dtype=float32), array(0.67292565, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# epoch:9  d_loss:0.6726  g_loss: [array(0.6742942, dtype=float32), array(0.6742942, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# epoch:10  d_loss:0.6741  g_loss: [array(0.6758385, dtype=float32), array(0.6758385, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# epoch:11  d_loss:0.6754  g_loss: [array(0.6771157, dtype=float32), array(0.6771157, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:12  d_loss:0.6768  g_loss: [array(0.6783672, dtype=float32), array(0.6783672, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# epoch:13  d_loss:0.6779  g_loss: [array(0.67941964, dtype=float32), array(0.67941964, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# epoch:14  d_loss:0.6789  g_loss: [array(0.68019634, dtype=float32), array(0.68019634, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# epoch:15  d_loss:0.6801  g_loss: [array(0.6813491, dtype=float32), array(0.6813491, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# epoch:16  d_loss:0.6813  g_loss: [array(0.6826391, dtype=float32), array(0.6826391, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# epoch:17  d_loss:0.6823  g_loss: [array(0.68363345, dtype=float32), array(0.68363345, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# epoch:18  d_loss:0.6833  g_loss: [array(0.68463784, dtype=float32), array(0.68463784, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:19  d_loss:0.6841  g_loss: [array(0.6853394, dtype=float32), array(0.6853394, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# epoch:20  d_loss:0.6852  g_loss: [array(0.6864633, dtype=float32), array(0.6864633, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# epoch:21  d_loss:0.6864  g_loss: [array(0.6875182, dtype=float32), array(0.6875182, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# epoch:22  d_loss:0.6876  g_loss: [array(0.688805, dtype=float32), array(0.688805, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:23  d_loss:0.6888  g_loss: [array(0.68984413, dtype=float32), array(0.68984413, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# epoch:24  d_loss:0.6899  g_loss: [array(0.6909616, dtype=float32), array(0.6909616, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# epoch:25  d_loss:0.6911  g_loss: [array(0.69221264, dtype=float32), array(0.69221264, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# epoch:26  d_loss:0.6920  g_loss: [array(0.69309735, dtype=float32), array(0.69309735, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# epoch:27  d_loss:0.6929  g_loss: [array(0.69383055, dtype=float32), array(0.69383055, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# epoch:28  d_loss:0.6936  g_loss: [array(0.6945564, dtype=float32), array(0.6945564, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# epoch:29  d_loss:0.6944  g_loss: [array(0.69539654, dtype=float32), array(0.69539654, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# epoch:30  d_loss:0.6954  g_loss: [array(0.69643843, dtype=float32), array(0.69643843, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# epoch:31  d_loss:0.6962  g_loss: [array(0.69707566, dtype=float32), array(0.69707566, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# epoch:32  d_loss:0.6972  g_loss: [array(0.69813293, dtype=float32), array(0.69813293, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:33  d_loss:0.6981  g_loss: [array(0.69905996, dtype=float32), array(0.69905996, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# epoch:34  d_loss:0.6990  g_loss: [array(0.6999195, dtype=float32), array(0.6999195, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# epoch:35  d_loss:0.6998  g_loss: [array(0.7006336, dtype=float32), array(0.7006336, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:36  d_loss:0.7004  g_loss: [array(0.7013162, dtype=float32), array(0.7013162, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# epoch:37  d_loss:0.7012  g_loss: [array(0.70208025, dtype=float32), array(0.70208025, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# epoch:38  d_loss:0.7019  g_loss: [array(0.7027246, dtype=float32), array(0.7027246, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# epoch:39  d_loss:0.7026  g_loss: [array(0.703416, dtype=float32), array(0.703416, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:40  d_loss:0.7032  g_loss: [array(0.7040506, dtype=float32), array(0.7040506, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:41  d_loss:0.7040  g_loss: [array(0.70488787, dtype=float32), array(0.70488787, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# epoch:42  d_loss:0.7048  g_loss: [array(0.70563984, dtype=float32), array(0.70563984, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:43  d_loss:0.7056  g_loss: [array(0.7064031, dtype=float32), array(0.7064031, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# epoch:44  d_loss:0.7063  g_loss: [array(0.70710534, dtype=float32), array(0.70710534, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# epoch:45  d_loss:0.7070  g_loss: [array(0.70785123, dtype=float32), array(0.70785123, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:46  d_loss:0.7077  g_loss: [array(0.7085576, dtype=float32), array(0.7085576, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# epoch:47  d_loss:0.7085  g_loss: [array(0.7093365, dtype=float32), array(0.7093365, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# epoch:48  d_loss:0.7096  g_loss: [array(0.71045333, dtype=float32), array(0.71045333, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# epoch:49  d_loss:0.7103  g_loss: [array(0.7110611, dtype=float32), array(0.7110611, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# epoch:50  d_loss:0.7111  g_loss: [array(0.71183574, dtype=float32), array(0.71183574, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:51  d_loss:0.7118  g_loss: [array(0.71255183, dtype=float32), array(0.71255183, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:52  d_loss:0.7125  g_loss: [array(0.7132573, dtype=float32), array(0.7132573, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# epoch:53  d_loss:0.7133  g_loss: [array(0.7140752, dtype=float32), array(0.7140752, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:54  d_loss:0.7141  g_loss: [array(0.71485484, dtype=float32), array(0.71485484, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:55  d_loss:0.7149  g_loss: [array(0.7156471, dtype=float32), array(0.7156471, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# epoch:56  d_loss:0.7157  g_loss: [array(0.7164269, dtype=float32), array(0.7164269, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:57  d_loss:0.7164  g_loss: [array(0.717157, dtype=float32), array(0.717157, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:58  d_loss:0.7171  g_loss: [array(0.7178422, dtype=float32), array(0.7178422, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# epoch:59  d_loss:0.7178  g_loss: [array(0.71863014, dtype=float32), array(0.71863014, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# epoch:60  d_loss:0.7186  g_loss: [array(0.71938217, dtype=float32), array(0.71938217, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:61  d_loss:0.7195  g_loss: [array(0.7203012, dtype=float32), array(0.7203012, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# epoch:62  d_loss:0.7203  g_loss: [array(0.72100806, dtype=float32), array(0.72100806, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:63  d_loss:0.7210  g_loss: [array(0.7217512, dtype=float32), array(0.7217512, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# epoch:64  d_loss:0.7218  g_loss: [array(0.72248673, dtype=float32), array(0.72248673, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# epoch:65  d_loss:0.7225  g_loss: [array(0.7232893, dtype=float32), array(0.7232893, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:66  d_loss:0.7234  g_loss: [array(0.72422475, dtype=float32), array(0.72422475, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# epoch:67  d_loss:0.7243  g_loss: [array(0.7250826, dtype=float32), array(0.7250826, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# epoch:68  d_loss:0.7250  g_loss: [array(0.72573483, dtype=float32), array(0.72573483, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:69  d_loss:0.7258  g_loss: [array(0.72649544, dtype=float32), array(0.72649544, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# epoch:70  d_loss:0.7265  g_loss: [array(0.7272093, dtype=float32), array(0.7272093, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# epoch:71  d_loss:0.7273  g_loss: [array(0.7279854, dtype=float32), array(0.7279854, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# epoch:72  d_loss:0.7280  g_loss: [array(0.72878337, dtype=float32), array(0.72878337, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# epoch:73  d_loss:0.7289  g_loss: [array(0.7296266, dtype=float32), array(0.7296266, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# epoch:74  d_loss:0.7297  g_loss: [array(0.73047906, dtype=float32), array(0.73047906, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# epoch:75  d_loss:0.7305  g_loss: [array(0.73122424, dtype=float32), array(0.73122424, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# epoch:76  d_loss:0.7313  g_loss: [array(0.73202616, dtype=float32), array(0.73202616, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# epoch:77  d_loss:0.7320  g_loss: [array(0.73270273, dtype=float32), array(0.73270273, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# epoch:78  d_loss:0.7328  g_loss: [array(0.7335537, dtype=float32), array(0.7335537, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# epoch:79  d_loss:0.7336  g_loss: [array(0.7343954, dtype=float32), array(0.7343954, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# epoch:80  d_loss:0.7345  g_loss: [array(0.7352744, dtype=float32), array(0.7352744, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# epoch:81  d_loss:0.7353  g_loss: [array(0.736056, dtype=float32), array(0.736056, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# epoch:82  d_loss:0.7361  g_loss: [array(0.73681927, dtype=float32), array(0.73681927, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:83  d_loss:0.7368  g_loss: [array(0.73755383, dtype=float32), array(0.73755383, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:84  d_loss:0.7376  g_loss: [array(0.73836774, dtype=float32), array(0.73836774, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# epoch:85  d_loss:0.7384  g_loss: [array(0.73916155, dtype=float32), array(0.73916155, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# epoch:86  d_loss:0.7393  g_loss: [array(0.7399861, dtype=float32), array(0.7399861, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:87  d_loss:0.7401  g_loss: [array(0.74077874, dtype=float32), array(0.74077874, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# epoch:88  d_loss:0.7409  g_loss: [array(0.74164313, dtype=float32), array(0.74164313, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# epoch:89  d_loss:0.7417  g_loss: [array(0.74233574, dtype=float32), array(0.74233574, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:90  d_loss:0.7424  g_loss: [array(0.7431637, dtype=float32), array(0.7431637, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:91  d_loss:0.7433  g_loss: [array(0.7440332, dtype=float32), array(0.7440332, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# epoch:92  d_loss:0.7441  g_loss: [array(0.74486107, dtype=float32), array(0.74486107, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# epoch:93  d_loss:0.7449  g_loss: [array(0.7455561, dtype=float32), array(0.7455561, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:94  d_loss:0.7456  g_loss: [array(0.7462991, dtype=float32), array(0.7462991, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# epoch:95  d_loss:0.7464  g_loss: [array(0.74713373, dtype=float32), array(0.74713373, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# epoch:96  d_loss:0.7472  g_loss: [array(0.74791366, dtype=float32), array(0.74791366, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# epoch:97  d_loss:0.7480  g_loss: [array(0.7487116, dtype=float32), array(0.7487116, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# epoch:98  d_loss:0.7488  g_loss: [array(0.7495778, dtype=float32), array(0.7495778, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# epoch:99  d_loss:0.7497  g_loss: [array(0.7504755, dtype=float32), array(0.7504755, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# epoch:100  d_loss:0.7506  g_loss: [array(0.7512826, dtype=float32), array(0.7512826, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# epoch:101  d_loss:0.7514  g_loss: [array(0.75211775, dtype=float32), array(0.75211775, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# epoch:102  d_loss:0.7522  g_loss: [array(0.75299203, dtype=float32), array(0.75299203, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# epoch:103  d_loss:0.7531  g_loss: [array(0.75387394, dtype=float32), array(0.75387394, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# epoch:104  d_loss:0.7540  g_loss: [array(0.75477296, dtype=float32), array(0.75477296, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# epoch:105  d_loss:0.7549  g_loss: [array(0.755635, dtype=float32), array(0.755635, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:106  d_loss:0.7557  g_loss: [array(0.7564737, dtype=float32), array(0.7564737, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# epoch:107  d_loss:0.7566  g_loss: [array(0.7573707, dtype=float32), array(0.7573707, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# epoch:108  d_loss:0.7575  g_loss: [array(0.75826573, dtype=float32), array(0.75826573, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# epoch:109  d_loss:0.7584  g_loss: [array(0.7591191, dtype=float32), array(0.7591191, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# epoch:110  d_loss:0.7593  g_loss: [array(0.7600547, dtype=float32), array(0.7600547, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# epoch:111  d_loss:0.7602  g_loss: [array(0.7609295, dtype=float32), array(0.7609295, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# epoch:112  d_loss:0.7611  g_loss: [array(0.7618391, dtype=float32), array(0.7618391, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:113  d_loss:0.7619  g_loss: [array(0.76269114, dtype=float32), array(0.76269114, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# epoch:114  d_loss:0.7628  g_loss: [array(0.7635383, dtype=float32), array(0.7635383, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:115  d_loss:0.7636  g_loss: [array(0.7643687, dtype=float32), array(0.7643687, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# epoch:116  d_loss:0.7645  g_loss: [array(0.76529515, dtype=float32), array(0.76529515, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:117  d_loss:0.7655  g_loss: [array(0.7662043, dtype=float32), array(0.7662043, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# epoch:118  d_loss:0.7664  g_loss: [array(0.76716375, dtype=float32), array(0.76716375, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# epoch:119  d_loss:0.7673  g_loss: [array(0.7680376, dtype=float32), array(0.7680376, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# epoch:120  d_loss:0.7682  g_loss: [array(0.7689403, dtype=float32), array(0.7689403, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# epoch:121  d_loss:0.7691  g_loss: [array(0.7698531, dtype=float32), array(0.7698531, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# epoch:122  d_loss:0.7701  g_loss: [array(0.7708203, dtype=float32), array(0.7708203, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# epoch:123  d_loss:0.7710  g_loss: [array(0.7717286, dtype=float32), array(0.7717286, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:124  d_loss:0.7719  g_loss: [array(0.7726947, dtype=float32), array(0.7726947, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# epoch:125  d_loss:0.7728  g_loss: [array(0.77357197, dtype=float32), array(0.77357197, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# epoch:126  d_loss:0.7738  g_loss: [array(0.7745228, dtype=float32), array(0.7745228, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:127  d_loss:0.7747  g_loss: [array(0.7754424, dtype=float32), array(0.7754424, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:128  d_loss:0.7757  g_loss: [array(0.77640975, dtype=float32), array(0.77640975, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# epoch:129  d_loss:0.7766  g_loss: [array(0.7773157, dtype=float32), array(0.7773157, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# epoch:130  d_loss:0.7775  g_loss: [array(0.77827233, dtype=float32), array(0.77827233, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# epoch:131  d_loss:0.7785  g_loss: [array(0.7792424, dtype=float32), array(0.7792424, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# epoch:132  d_loss:0.7794  g_loss: [array(0.7802035, dtype=float32), array(0.7802035, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:133  d_loss:0.7804  g_loss: [array(0.7811395, dtype=float32), array(0.7811395, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:134  d_loss:0.7813  g_loss: [array(0.78205425, dtype=float32), array(0.78205425, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:135  d_loss:0.7822  g_loss: [array(0.78293896, dtype=float32), array(0.78293896, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# epoch:136  d_loss:0.7831  g_loss: [array(0.7838447, dtype=float32), array(0.7838447, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# epoch:137  d_loss:0.7841  g_loss: [array(0.7848669, dtype=float32), array(0.7848669, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:138  d_loss:0.7851  g_loss: [array(0.78589135, dtype=float32), array(0.78589135, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# epoch:139  d_loss:0.7861  g_loss: [array(0.786802, dtype=float32), array(0.786802, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# epoch:140  d_loss:0.7870  g_loss: [array(0.78778946, dtype=float32), array(0.78778946, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# epoch:141  d_loss:0.7880  g_loss: [array(0.78875035, dtype=float32), array(0.78875035, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:142  d_loss:0.7890  g_loss: [array(0.7897354, dtype=float32), array(0.7897354, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:143  d_loss:0.7900  g_loss: [array(0.79074633, dtype=float32), array(0.79074633, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:144  d_loss:0.7909  g_loss: [array(0.79170626, dtype=float32), array(0.79170626, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:145  d_loss:0.7919  g_loss: [array(0.7926464, dtype=float32), array(0.7926464, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# epoch:146  d_loss:0.7929  g_loss: [array(0.79365104, dtype=float32), array(0.79365104, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:147  d_loss:0.7939  g_loss: [array(0.7946577, dtype=float32), array(0.7946577, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# epoch:148  d_loss:0.7948  g_loss: [array(0.79557484, dtype=float32), array(0.79557484, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:149  d_loss:0.7958  g_loss: [array(0.79651976, dtype=float32), array(0.79651976, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# epoch:150  d_loss:0.7967  g_loss: [array(0.79749423, dtype=float32), array(0.79749423, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# epoch:151  d_loss:0.7977  g_loss: [array(0.7984754, dtype=float32), array(0.7984754, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# epoch:152  d_loss:0.7987  g_loss: [array(0.7994849, dtype=float32), array(0.7994849, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# epoch:153  d_loss:0.7997  g_loss: [array(0.80045205, dtype=float32), array(0.80045205, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# epoch:154  d_loss:0.8007  g_loss: [array(0.8014215, dtype=float32), array(0.8014215, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# epoch:155  d_loss:0.8016  g_loss: [array(0.8022924, dtype=float32), array(0.8022924, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# epoch:156  d_loss:0.8025  g_loss: [array(0.8032573, dtype=float32), array(0.8032573, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:157  d_loss:0.8035  g_loss: [array(0.80424154, dtype=float32), array(0.80424154, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# epoch:158  d_loss:0.8044  g_loss: [array(0.8051838, dtype=float32), array(0.8051838, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# epoch:159  d_loss:0.8054  g_loss: [array(0.8061492, dtype=float32), array(0.8061492, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# epoch:160  d_loss:0.8063  g_loss: [array(0.80707836, dtype=float32), array(0.80707836, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# epoch:161  d_loss:0.8073  g_loss: [array(0.8080295, dtype=float32), array(0.8080295, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:162  d_loss:0.8083  g_loss: [array(0.8090479, dtype=float32), array(0.8090479, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# epoch:163  d_loss:0.8092  g_loss: [array(0.8099607, dtype=float32), array(0.8099607, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# epoch:164  d_loss:0.8101  g_loss: [array(0.8108601, dtype=float32), array(0.8108601, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# epoch:165  d_loss:0.8110  g_loss: [array(0.81178916, dtype=float32), array(0.81178916, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:166  d_loss:0.8120  g_loss: [array(0.8127724, dtype=float32), array(0.8127724, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# epoch:167  d_loss:0.8130  g_loss: [array(0.8136907, dtype=float32), array(0.8136907, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:168  d_loss:0.8139  g_loss: [array(0.8146123, dtype=float32), array(0.8146123, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:169  d_loss:0.8148  g_loss: [array(0.8155297, dtype=float32), array(0.8155297, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# epoch:170  d_loss:0.8158  g_loss: [array(0.81651086, dtype=float32), array(0.81651086, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# epoch:171  d_loss:0.8167  g_loss: [array(0.8175048, dtype=float32), array(0.8175048, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# epoch:172  d_loss:0.8177  g_loss: [array(0.81849545, dtype=float32), array(0.81849545, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:173  d_loss:0.8187  g_loss: [array(0.8194724, dtype=float32), array(0.8194724, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:174  d_loss:0.8197  g_loss: [array(0.8204317, dtype=float32), array(0.8204317, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# epoch:175  d_loss:0.8207  g_loss: [array(0.82141435, dtype=float32), array(0.82141435, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:176  d_loss:0.8216  g_loss: [array(0.8223736, dtype=float32), array(0.8223736, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:177  d_loss:0.8226  g_loss: [array(0.82336015, dtype=float32), array(0.82336015, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:178  d_loss:0.8235  g_loss: [array(0.82427484, dtype=float32), array(0.82427484, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:179  d_loss:0.8245  g_loss: [array(0.82520235, dtype=float32), array(0.82520235, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# epoch:180  d_loss:0.8254  g_loss: [array(0.8261535, dtype=float32), array(0.8261535, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# epoch:181  d_loss:0.8264  g_loss: [array(0.82710904, dtype=float32), array(0.82710904, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# epoch:182  d_loss:0.8273  g_loss: [array(0.8280037, dtype=float32), array(0.8280037, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# epoch:183  d_loss:0.8282  g_loss: [array(0.82895285, dtype=float32), array(0.82895285, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:184  d_loss:0.8292  g_loss: [array(0.8299043, dtype=float32), array(0.8299043, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# epoch:185  d_loss:0.8301  g_loss: [array(0.83083665, dtype=float32), array(0.83083665, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# epoch:186  d_loss:0.8310  g_loss: [array(0.8318133, dtype=float32), array(0.8318133, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# epoch:187  d_loss:0.8320  g_loss: [array(0.8327963, dtype=float32), array(0.8327963, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:188  d_loss:0.8330  g_loss: [array(0.8337004, dtype=float32), array(0.8337004, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:189  d_loss:0.8339  g_loss: [array(0.834655, dtype=float32), array(0.834655, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# epoch:190  d_loss:0.8349  g_loss: [array(0.83560044, dtype=float32), array(0.83560044, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# epoch:191  d_loss:0.8359  g_loss: [array(0.8365896, dtype=float32), array(0.8365896, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# epoch:192  d_loss:0.8367  g_loss: [array(0.8374848, dtype=float32), array(0.8374848, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# epoch:193  d_loss:0.8377  g_loss: [array(0.8383959, dtype=float32), array(0.8383959, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# epoch:194  d_loss:0.8386  g_loss: [array(0.8393484, dtype=float32), array(0.8393484, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# epoch:195  d_loss:0.8395  g_loss: [array(0.8402753, dtype=float32), array(0.8402753, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# epoch:196  d_loss:0.8405  g_loss: [array(0.841225, dtype=float32), array(0.841225, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:197  d_loss:0.8414  g_loss: [array(0.8421709, dtype=float32), array(0.8421709, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# epoch:198  d_loss:0.8423  g_loss: [array(0.8430507, dtype=float32), array(0.8430507, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# epoch:199  d_loss:0.8432  g_loss: [array(0.8439623, dtype=float32), array(0.8439623, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# epoch:200  d_loss:0.8441  g_loss: [array(0.8448523, dtype=float32), array(0.8448523, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# epoch:201  d_loss:0.8450  g_loss: [array(0.8457226, dtype=float32), array(0.8457226, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# epoch:202  d_loss:0.8459  g_loss: [array(0.8466485, dtype=float32), array(0.8466485, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# epoch:203  d_loss:0.8468  g_loss: [array(0.8475286, dtype=float32), array(0.8475286, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# epoch:204  d_loss:0.8477  g_loss: [array(0.848474, dtype=float32), array(0.848474, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# epoch:205  d_loss:0.8487  g_loss: [array(0.8493924, dtype=float32), array(0.8493924, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:206  d_loss:0.8496  g_loss: [array(0.85031974, dtype=float32), array(0.85031974, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# epoch:207  d_loss:0.8505  g_loss: [array(0.85127, dtype=float32), array(0.85127, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# epoch:208  d_loss:0.8514  g_loss: [array(0.8521577, dtype=float32), array(0.8521577, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# epoch:209  d_loss:0.8523  g_loss: [array(0.85308343, dtype=float32), array(0.85308343, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# epoch:210  d_loss:0.8533  g_loss: [array(0.85399383, dtype=float32), array(0.85399383, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# epoch:211  d_loss:0.8542  g_loss: [array(0.85488385, dtype=float32), array(0.85488385, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# epoch:212  d_loss:0.8551  g_loss: [array(0.85582036, dtype=float32), array(0.85582036, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# epoch:213  d_loss:0.8560  g_loss: [array(0.8567627, dtype=float32), array(0.8567627, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:214  d_loss:0.8569  g_loss: [array(0.8576641, dtype=float32), array(0.8576641, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:215  d_loss:0.8579  g_loss: [array(0.8585591, dtype=float32), array(0.8585591, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# epoch:216  d_loss:0.8588  g_loss: [array(0.85951394, dtype=float32), array(0.85951394, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:217  d_loss:0.8597  g_loss: [array(0.8604126, dtype=float32), array(0.8604126, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# epoch:218  d_loss:0.8606  g_loss: [array(0.8613218, dtype=float32), array(0.8613218, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:219  d_loss:0.8615  g_loss: [array(0.8622219, dtype=float32), array(0.8622219, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:220  d_loss:0.8624  g_loss: [array(0.8631678, dtype=float32), array(0.8631678, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# epoch:221  d_loss:0.8634  g_loss: [array(0.864074, dtype=float32), array(0.864074, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:222  d_loss:0.8643  g_loss: [array(0.86499643, dtype=float32), array(0.86499643, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:223  d_loss:0.8652  g_loss: [array(0.8658949, dtype=float32), array(0.8658949, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# epoch:224  d_loss:0.8661  g_loss: [array(0.8667814, dtype=float32), array(0.8667814, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:225  d_loss:0.8670  g_loss: [array(0.8676743, dtype=float32), array(0.8676743, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:226  d_loss:0.8679  g_loss: [array(0.8685944, dtype=float32), array(0.8685944, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:227  d_loss:0.8688  g_loss: [array(0.8694829, dtype=float32), array(0.8694829, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# epoch:228  d_loss:0.8697  g_loss: [array(0.870364, dtype=float32), array(0.870364, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:229  d_loss:0.8705  g_loss: [array(0.8712234, dtype=float32), array(0.8712234, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:230  d_loss:0.8714  g_loss: [array(0.87208164, dtype=float32), array(0.87208164, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# epoch:231  d_loss:0.8723  g_loss: [array(0.87294424, dtype=float32), array(0.87294424, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# epoch:232  d_loss:0.8731  g_loss: [array(0.87382686, dtype=float32), array(0.87382686, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# epoch:233  d_loss:0.8740  g_loss: [array(0.8747456, dtype=float32), array(0.8747456, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# epoch:234  d_loss:0.8749  g_loss: [array(0.87560785, dtype=float32), array(0.87560785, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:235  d_loss:0.8758  g_loss: [array(0.8764382, dtype=float32), array(0.8764382, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# epoch:236  d_loss:0.8766  g_loss: [array(0.87730306, dtype=float32), array(0.87730306, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# epoch:237  d_loss:0.8775  g_loss: [array(0.8782252, dtype=float32), array(0.8782252, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:238  d_loss:0.8784  g_loss: [array(0.87913185, dtype=float32), array(0.87913185, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# epoch:239  d_loss:0.8793  g_loss: [array(0.8799835, dtype=float32), array(0.8799835, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# epoch:240  d_loss:0.8802  g_loss: [array(0.88085264, dtype=float32), array(0.88085264, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# epoch:241  d_loss:0.8810  g_loss: [array(0.88169736, dtype=float32), array(0.88169736, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# epoch:242  d_loss:0.8818  g_loss: [array(0.8825296, dtype=float32), array(0.8825296, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# epoch:243  d_loss:0.8827  g_loss: [array(0.8833876, dtype=float32), array(0.8833876, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# epoch:244  d_loss:0.8836  g_loss: [array(0.88424295, dtype=float32), array(0.88424295, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# epoch:245  d_loss:0.8844  g_loss: [array(0.88512725, dtype=float32), array(0.88512725, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# epoch:246  d_loss:0.8853  g_loss: [array(0.88596976, dtype=float32), array(0.88596976, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# epoch:247  d_loss:0.8862  g_loss: [array(0.88689387, dtype=float32), array(0.88689387, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# epoch:248  d_loss:0.8871  g_loss: [array(0.8877911, dtype=float32), array(0.8877911, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# epoch:249  d_loss:0.8880  g_loss: [array(0.88862026, dtype=float32), array(0.88862026, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# epoch:250  d_loss:0.8888  g_loss: [array(0.8894909, dtype=float32), array(0.8894909, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# epoch:251  d_loss:0.8896  g_loss: [array(0.890284, dtype=float32), array(0.890284, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# epoch:252  d_loss:0.8904  g_loss: [array(0.89111984, dtype=float32), array(0.89111984, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# epoch:253  d_loss:0.8913  g_loss: [array(0.89194393, dtype=float32), array(0.89194393, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# epoch:254  d_loss:0.8921  g_loss: [array(0.8928216, dtype=float32), array(0.8928216, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# epoch:255  d_loss:0.8929  g_loss: [array(0.89361227, dtype=float32), array(0.89361227, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# epoch:256  d_loss:0.8937  g_loss: [array(0.89438057, dtype=float32), array(0.89438057, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# epoch:257  d_loss:0.8946  g_loss: [array(0.89527243, dtype=float32), array(0.89527243, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# epoch:258  d_loss:0.8954  g_loss: [array(0.89612824, dtype=float32), array(0.89612824, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# epoch:259  d_loss:0.8963  g_loss: [array(0.8969562, dtype=float32), array(0.8969562, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# epoch:260  d_loss:0.8971  g_loss: [array(0.8977399, dtype=float32), array(0.8977399, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# epoch:261  d_loss:0.8979  g_loss: [array(0.89851946, dtype=float32), array(0.89851946, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# epoch:262  d_loss:0.8987  g_loss: [array(0.89931655, dtype=float32), array(0.89931655, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# epoch:263  d_loss:0.8994  g_loss: [array(0.90008605, dtype=float32), array(0.90008605, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# epoch:264  d_loss:0.9002  g_loss: [array(0.9009131, dtype=float32), array(0.9009131, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# epoch:265  d_loss:0.9010  g_loss: [array(0.9016903, dtype=float32), array(0.9016903, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# epoch:266  d_loss:0.9018  g_loss: [array(0.90248424, dtype=float32), array(0.90248424, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# epoch:267  d_loss:0.9026  g_loss: [array(0.9032596, dtype=float32), array(0.9032596, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# epoch:268  d_loss:0.9034  g_loss: [array(0.9040561, dtype=float32), array(0.9040561, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:269  d_loss:0.9042  g_loss: [array(0.90484685, dtype=float32), array(0.90484685, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# epoch:270  d_loss:0.9050  g_loss: [array(0.90566885, dtype=float32), array(0.90566885, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# epoch:271  d_loss:0.9058  g_loss: [array(0.90644264, dtype=float32), array(0.90644264, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# epoch:272  d_loss:0.9066  g_loss: [array(0.907246, dtype=float32), array(0.907246, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# epoch:273  d_loss:0.9074  g_loss: [array(0.90806407, dtype=float32), array(0.90806407, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:274  d_loss:0.9082  g_loss: [array(0.90890396, dtype=float32), array(0.90890396, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# epoch:275  d_loss:0.9091  g_loss: [array(0.9097374, dtype=float32), array(0.9097374, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# epoch:276  d_loss:0.9099  g_loss: [array(0.9105338, dtype=float32), array(0.9105338, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# epoch:277  d_loss:0.9106  g_loss: [array(0.9112857, dtype=float32), array(0.9112857, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# epoch:278  d_loss:0.9114  g_loss: [array(0.9120471, dtype=float32), array(0.9120471, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# epoch:279  d_loss:0.9122  g_loss: [array(0.91282094, dtype=float32), array(0.91282094, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# epoch:280  d_loss:0.9130  g_loss: [array(0.9136318, dtype=float32), array(0.9136318, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# epoch:281  d_loss:0.9138  g_loss: [array(0.91442645, dtype=float32), array(0.91442645, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# epoch:282  d_loss:0.9146  g_loss: [array(0.91517967, dtype=float32), array(0.91517967, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# epoch:283  d_loss:0.9153  g_loss: [array(0.91596466, dtype=float32), array(0.91596466, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# epoch:284  d_loss:0.9161  g_loss: [array(0.916723, dtype=float32), array(0.916723, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# epoch:285  d_loss:0.9169  g_loss: [array(0.9175443, dtype=float32), array(0.9175443, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:286  d_loss:0.9177  g_loss: [array(0.9183189, dtype=float32), array(0.9183189, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# epoch:287  d_loss:0.9184  g_loss: [array(0.91903454, dtype=float32), array(0.91903454, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# epoch:288  d_loss:0.9192  g_loss: [array(0.91980237, dtype=float32), array(0.91980237, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# epoch:289  d_loss:0.9200  g_loss: [array(0.9206047, dtype=float32), array(0.9206047, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# epoch:290  d_loss:0.9207  g_loss: [array(0.9213388, dtype=float32), array(0.9213388, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# epoch:291  d_loss:0.9215  g_loss: [array(0.9220952, dtype=float32), array(0.9220952, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# epoch:292  d_loss:0.9222  g_loss: [array(0.92287207, dtype=float32), array(0.92287207, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# epoch:293  d_loss:0.9230  g_loss: [array(0.9236306, dtype=float32), array(0.9236306, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# epoch:294  d_loss:0.9237  g_loss: [array(0.9243553, dtype=float32), array(0.9243553, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# epoch:295  d_loss:0.9245  g_loss: [array(0.92508066, dtype=float32), array(0.92508066, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# epoch:296  d_loss:0.9252  g_loss: [array(0.9258061, dtype=float32), array(0.9258061, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# epoch:297  d_loss:0.9259  g_loss: [array(0.92656744, dtype=float32), array(0.92656744, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# epoch:298  d_loss:0.9267  g_loss: [array(0.9272957, dtype=float32), array(0.9272957, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# epoch:299  d_loss:0.9274  g_loss: [array(0.9280126, dtype=float32), array(0.9280126, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:300  d_loss:0.9281  g_loss: [array(0.9287579, dtype=float32), array(0.9287579, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# epoch:301  d_loss:0.9289  g_loss: [array(0.92948925, dtype=float32), array(0.92948925, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# epoch:302  d_loss:0.9296  g_loss: [array(0.93023944, dtype=float32), array(0.93023944, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:303  d_loss:0.9304  g_loss: [array(0.9309675, dtype=float32), array(0.9309675, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# epoch:304  d_loss:0.9311  g_loss: [array(0.9317177, dtype=float32), array(0.9317177, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:305  d_loss:0.9318  g_loss: [array(0.9324455, dtype=float32), array(0.9324455, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# epoch:306  d_loss:0.9326  g_loss: [array(0.9331793, dtype=float32), array(0.9331793, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# epoch:307  d_loss:0.9333  g_loss: [array(0.9339311, dtype=float32), array(0.9339311, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:308  d_loss:0.9340  g_loss: [array(0.93463814, dtype=float32), array(0.93463814, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# epoch:309  d_loss:0.9348  g_loss: [array(0.9353733, dtype=float32), array(0.9353733, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# epoch:310  d_loss:0.9355  g_loss: [array(0.9360892, dtype=float32), array(0.9360892, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# epoch:311  d_loss:0.9362  g_loss: [array(0.936798, dtype=float32), array(0.936798, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:312  d_loss:0.9369  g_loss: [array(0.9375034, dtype=float32), array(0.9375034, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# epoch:313  d_loss:0.9376  g_loss: [array(0.938233, dtype=float32), array(0.938233, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# epoch:314  d_loss:0.9384  g_loss: [array(0.9389757, dtype=float32), array(0.9389757, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# epoch:315  d_loss:0.9391  g_loss: [array(0.9396669, dtype=float32), array(0.9396669, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# epoch:316  d_loss:0.9398  g_loss: [array(0.94033766, dtype=float32), array(0.94033766, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# epoch:317  d_loss:0.9405  g_loss: [array(0.94105923, dtype=float32), array(0.94105923, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:318  d_loss:0.9412  g_loss: [array(0.9418049, dtype=float32), array(0.9418049, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# epoch:319  d_loss:0.9419  g_loss: [array(0.94252694, dtype=float32), array(0.94252694, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:320  d_loss:0.9426  g_loss: [array(0.9432105, dtype=float32), array(0.9432105, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# epoch:321  d_loss:0.9433  g_loss: [array(0.9439058, dtype=float32), array(0.9439058, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# epoch:322  d_loss:0.9440  g_loss: [array(0.9446549, dtype=float32), array(0.9446549, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# epoch:323  d_loss:0.9448  g_loss: [array(0.9453562, dtype=float32), array(0.9453562, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# epoch:324  d_loss:0.9454  g_loss: [array(0.94601965, dtype=float32), array(0.94601965, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# epoch:325  d_loss:0.9461  g_loss: [array(0.9466783, dtype=float32), array(0.9466783, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# epoch:326  d_loss:0.9468  g_loss: [array(0.9473441, dtype=float32), array(0.9473441, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:327  d_loss:0.9474  g_loss: [array(0.9480266, dtype=float32), array(0.9480266, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# epoch:328  d_loss:0.9482  g_loss: [array(0.9487623, dtype=float32), array(0.9487623, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:329  d_loss:0.9489  g_loss: [array(0.9494678, dtype=float32), array(0.9494678, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:330  d_loss:0.9496  g_loss: [array(0.95019597, dtype=float32), array(0.95019597, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# ...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# epoch:1887  d_loss:1.2348  g_loss: [array(1.234884, dtype=float32), array(1.234884, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# epoch:1888  d_loss:1.2348  g_loss: [array(1.2349246, dtype=float32), array(1.2349246, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# epoch:1889  d_loss:1.2349  g_loss: [array(1.2349653, dtype=float32), array(1.2349653, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# epoch:1890  d_loss:1.2349  g_loss: [array(1.2350042, dtype=float32), array(1.2350042, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# epoch:1891  d_loss:1.2349  g_loss: [array(1.235052, dtype=float32), array(1.235052, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# epoch:1892  d_loss:1.2350  g_loss: [array(1.2350949, dtype=float32), array(1.2350949, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# epoch:1893  d_loss:1.2350  g_loss: [array(1.2351388, dtype=float32), array(1.2351388, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# epoch:1894  d_loss:1.2351  g_loss: [array(1.2351822, dtype=float32), array(1.2351822, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# epoch:1895  d_loss:1.2351  g_loss: [array(1.2352217, dtype=float32), array(1.2352217, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# epoch:1896  d_loss:1.2352  g_loss: [array(1.2352643, dtype=float32), array(1.2352643, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# epoch:1897  d_loss:1.2352  g_loss: [array(1.2353146, dtype=float32), array(1.2353146, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# epoch:1898  d_loss:1.2353  g_loss: [array(1.2353597, dtype=float32), array(1.2353597, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# epoch:1899  d_loss:1.2353  g_loss: [array(1.2354041, dtype=float32), array(1.2354041, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# epoch:1900  d_loss:1.2353  g_loss: [array(1.2354505, dtype=float32), array(1.2354505, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# epoch:1901  d_loss:1.2354  g_loss: [array(1.235498, dtype=float32), array(1.235498, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# epoch:1902  d_loss:1.2354  g_loss: [array(1.2355319, dtype=float32), array(1.2355319, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# epoch:1903  d_loss:1.2355  g_loss: [array(1.2355664, dtype=float32), array(1.2355664, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# epoch:1904  d_loss:1.2355  g_loss: [array(1.2356157, dtype=float32), array(1.2356157, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# epoch:1905  d_loss:1.2356  g_loss: [array(1.235653, dtype=float32), array(1.235653, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# epoch:1906  d_loss:1.2356  g_loss: [array(1.2356902, dtype=float32), array(1.2356902, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# epoch:1907  d_loss:1.2356  g_loss: [array(1.2357398, dtype=float32), array(1.2357398, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# epoch:1908  d_loss:1.2357  g_loss: [array(1.2357794, dtype=float32), array(1.2357794, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# epoch:1909  d_loss:1.2357  g_loss: [array(1.235826, dtype=float32), array(1.235826, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# epoch:1910  d_loss:1.2358  g_loss: [array(1.2358643, dtype=float32), array(1.2358643, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# epoch:1911  d_loss:1.2358  g_loss: [array(1.235907, dtype=float32), array(1.235907, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# epoch:1912  d_loss:1.2358  g_loss: [array(1.235949, dtype=float32), array(1.235949, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# epoch:1913  d_loss:1.2359  g_loss: [array(1.2359898, dtype=float32), array(1.2359898, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# epoch:1914  d_loss:1.2359  g_loss: [array(1.2360245, dtype=float32), array(1.2360245, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# epoch:1915  d_loss:1.2360  g_loss: [array(1.2360708, dtype=float32), array(1.2360708, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# epoch:1916  d_loss:1.2360  g_loss: [array(1.2361157, dtype=float32), array(1.2361157, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# epoch:1917  d_loss:1.2361  g_loss: [array(1.2361635, dtype=float32), array(1.2361635, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# epoch:1918  d_loss:1.2361  g_loss: [array(1.2362021, dtype=float32), array(1.2362021, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# epoch:1919  d_loss:1.2361  g_loss: [array(1.2362342, dtype=float32), array(1.2362342, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# epoch:1920  d_loss:1.2362  g_loss: [array(1.236276, dtype=float32), array(1.236276, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# epoch:1921  d_loss:1.2362  g_loss: [array(1.2363203, dtype=float32), array(1.2363203, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# epoch:1922  d_loss:1.2363  g_loss: [array(1.2363647, dtype=float32), array(1.2363647, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# epoch:1923  d_loss:1.2363  g_loss: [array(1.236425, dtype=float32), array(1.236425, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# epoch:1924  d_loss:1.2364  g_loss: [array(1.2364647, dtype=float32), array(1.2364647, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# epoch:1925  d_loss:1.2364  g_loss: [array(1.236509, dtype=float32), array(1.236509, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# epoch:1926  d_loss:1.2364  g_loss: [array(1.2365512, dtype=float32), array(1.2365512, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# epoch:1927  d_loss:1.2365  g_loss: [array(1.2365967, dtype=float32), array(1.2365967, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# epoch:1928  d_loss:1.2365  g_loss: [array(1.2366414, dtype=float32), array(1.2366414, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# epoch:1929  d_loss:1.2366  g_loss: [array(1.2366843, dtype=float32), array(1.2366843, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# epoch:1930  d_loss:1.2366  g_loss: [array(1.2367355, dtype=float32), array(1.2367355, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# epoch:1931  d_loss:1.2367  g_loss: [array(1.2367702, dtype=float32), array(1.2367702, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# epoch:1932  d_loss:1.2367  g_loss: [array(1.2368107, dtype=float32), array(1.2368107, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# epoch:1933  d_loss:1.2368  g_loss: [array(1.2368536, dtype=float32), array(1.2368536, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# epoch:1934  d_loss:1.2368  g_loss: [array(1.2368976, dtype=float32), array(1.2368976, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# epoch:1935  d_loss:1.2368  g_loss: [array(1.2369399, dtype=float32), array(1.2369399, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# epoch:1936  d_loss:1.2369  g_loss: [array(1.2369756, dtype=float32), array(1.2369756, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# epoch:1937  d_loss:1.2369  g_loss: [array(1.2370192, dtype=float32), array(1.2370192, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# epoch:1938  d_loss:1.2370  g_loss: [array(1.2370619, dtype=float32), array(1.2370619, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# epoch:1939  d_loss:1.2370  g_loss: [array(1.2371035, dtype=float32), array(1.2371035, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# epoch:1940  d_loss:1.2370  g_loss: [array(1.2371467, dtype=float32), array(1.2371467, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# epoch:1941  d_loss:1.2371  g_loss: [array(1.2371941, dtype=float32), array(1.2371941, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# epoch:1942  d_loss:1.2371  g_loss: [array(1.2372397, dtype=float32), array(1.2372397, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# epoch:1943  d_loss:1.2372  g_loss: [array(1.2372774, dtype=float32), array(1.2372774, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# epoch:1944  d_loss:1.2372  g_loss: [array(1.2373215, dtype=float32), array(1.2373215, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# epoch:1945  d_loss:1.2373  g_loss: [array(1.2373676, dtype=float32), array(1.2373676, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# epoch:1946  d_loss:1.2373  g_loss: [array(1.2374028, dtype=float32), array(1.2374028, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# epoch:1947  d_loss:1.2373  g_loss: [array(1.2374438, dtype=float32), array(1.2374438, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# epoch:1948  d_loss:1.2374  g_loss: [array(1.2374816, dtype=float32), array(1.2374816, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# epoch:1949  d_loss:1.2374  g_loss: [array(1.2375184, dtype=float32), array(1.2375184, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# epoch:1950  d_loss:1.2375  g_loss: [array(1.2375659, dtype=float32), array(1.2375659, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# epoch:1951  d_loss:1.2375  g_loss: [array(1.2376144, dtype=float32), array(1.2376144, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# epoch:1952  d_loss:1.2376  g_loss: [array(1.2376595, dtype=float32), array(1.2376595, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# epoch:1953  d_loss:1.2376  g_loss: [array(1.2376953, dtype=float32), array(1.2376953, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# epoch:1954  d_loss:1.2376  g_loss: [array(1.2377292, dtype=float32), array(1.2377292, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# epoch:1955  d_loss:1.2377  g_loss: [array(1.2377708, dtype=float32), array(1.2377708, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# epoch:1956  d_loss:1.2377  g_loss: [array(1.2378194, dtype=float32), array(1.2378194, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# epoch:1957  d_loss:1.2378  g_loss: [array(1.2378663, dtype=float32), array(1.2378663, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# epoch:1958  d_loss:1.2378  g_loss: [array(1.2379079, dtype=float32), array(1.2379079, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# epoch:1959  d_loss:1.2379  g_loss: [array(1.2379483, dtype=float32), array(1.2379483, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# epoch:1960  d_loss:1.2379  g_loss: [array(1.2379938, dtype=float32), array(1.2379938, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# epoch:1961  d_loss:1.2379  g_loss: [array(1.2380459, dtype=float32), array(1.2380459, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# epoch:1962  d_loss:1.2380  g_loss: [array(1.2380829, dtype=float32), array(1.2380829, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# epoch:1963  d_loss:1.2380  g_loss: [array(1.2381247, dtype=float32), array(1.2381247, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# epoch:1964  d_loss:1.2381  g_loss: [array(1.238169, dtype=float32), array(1.238169, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# epoch:1965  d_loss:1.2381  g_loss: [array(1.2382101, dtype=float32), array(1.2382101, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# epoch:1966  d_loss:1.2382  g_loss: [array(1.2382474, dtype=float32), array(1.2382474, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# epoch:1967  d_loss:1.2382  g_loss: [array(1.238289, dtype=float32), array(1.238289, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# epoch:1968  d_loss:1.2382  g_loss: [array(1.2383316, dtype=float32), array(1.2383316, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# epoch:1969  d_loss:1.2383  g_loss: [array(1.2383667, dtype=float32), array(1.2383667, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# epoch:1970  d_loss:1.2383  g_loss: [array(1.238412, dtype=float32), array(1.238412, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# epoch:1971  d_loss:1.2384  g_loss: [array(1.2384478, dtype=float32), array(1.2384478, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# epoch:1972  d_loss:1.2384  g_loss: [array(1.238489, dtype=float32), array(1.238489, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# epoch:1973  d_loss:1.2384  g_loss: [array(1.2385284, dtype=float32), array(1.2385284, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# epoch:1974  d_loss:1.2385  g_loss: [array(1.2385705, dtype=float32), array(1.2385705, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# epoch:1975  d_loss:1.2385  g_loss: [array(1.2386119, dtype=float32), array(1.2386119, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# epoch:1976  d_loss:1.2386  g_loss: [array(1.23865, dtype=float32), array(1.23865, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# epoch:1977  d_loss:1.2386  g_loss: [array(1.2386962, dtype=float32), array(1.2386962, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# epoch:1978  d_loss:1.2386  g_loss: [array(1.2387376, dtype=float32), array(1.2387376, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# epoch:1979  d_loss:1.2387  g_loss: [array(1.238785, dtype=float32), array(1.238785, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# epoch:1980  d_loss:1.2387  g_loss: [array(1.2388284, dtype=float32), array(1.2388284, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# epoch:1981  d_loss:1.2388  g_loss: [array(1.2388605, dtype=float32), array(1.2388605, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# epoch:1982  d_loss:1.2388  g_loss: [array(1.2389125, dtype=float32), array(1.2389125, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# epoch:1983  d_loss:1.2389  g_loss: [array(1.2389555, dtype=float32), array(1.2389555, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# epoch:1984  d_loss:1.2389  g_loss: [array(1.2390009, dtype=float32), array(1.2390009, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# epoch:1985  d_loss:1.2389  g_loss: [array(1.2390416, dtype=float32), array(1.2390416, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# epoch:1986  d_loss:1.2390  g_loss: [array(1.2390755, dtype=float32), array(1.2390755, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# epoch:1987  d_loss:1.2390  g_loss: [array(1.2391165, dtype=float32), array(1.2391165, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# epoch:1988  d_loss:1.2391  g_loss: [array(1.239158, dtype=float32), array(1.239158, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# epoch:1989  d_loss:1.2391  g_loss: [array(1.2392002, dtype=float32), array(1.2392002, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# epoch:1990  d_loss:1.2391  g_loss: [array(1.2392423, dtype=float32), array(1.2392423, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# epoch:1991  d_loss:1.2392  g_loss: [array(1.239286, dtype=float32), array(1.239286, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# epoch:1992  d_loss:1.2392  g_loss: [array(1.2393273, dtype=float32), array(1.2393273, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# epoch:1993  d_loss:1.2393  g_loss: [array(1.2393618, dtype=float32), array(1.2393618, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# epoch:1994  d_loss:1.2393  g_loss: [array(1.239405, dtype=float32), array(1.239405, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# epoch:1995  d_loss:1.2393  g_loss: [array(1.2394438, dtype=float32), array(1.2394438, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# epoch:1996  d_loss:1.2394  g_loss: [array(1.2394823, dtype=float32), array(1.2394823, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# epoch:1997  d_loss:1.2394  g_loss: [array(1.2395198, dtype=float32), array(1.2395198, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# epoch:1998  d_loss:1.2395  g_loss: [array(1.2395616, dtype=float32), array(1.2395616, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# epoch:1999  d_loss:1.2395  g_loss: [array(1.2395936, dtype=float32), array(1.2395936, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# epoch:2000  d_loss:1.2395  g_loss: [array(1.2396289, dtype=float32), array(1.2396289, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
